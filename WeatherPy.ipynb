# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
temp_units = "imperial"
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="
city_new = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []
count_one = 0
set_one = 1
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_new.append(city)
        else:
            count_one += 1
            city_new.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | krasnoselkup
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | oistins
# Processing Record 4 of Set 1 | vila franca do campo
# Processing Record 5 of Set 1 | ekuvukeni
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | cudahy
# Processing Record 8 of Set 1 | barrow
# City not found. Skipping...
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | pochutla
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | codrington
# Processing Record 13 of Set 1 | brae
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | tuatapere
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | oksfjord
# Processing Record 18 of Set 1 | pevek
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | guerrero negro
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | lompoc
# Processing Record 27 of Set 1 | cap-aux-meules
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | padang
# Processing Record 32 of Set 1 | tanjong sepat
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | bani walid
# Processing Record 36 of Set 1 | ponta do sol
# Processing Record 37 of Set 1 | aklavik
# Processing Record 38 of Set 1 | souillac
# Processing Record 39 of Set 1 | saldanha
# Processing Record 40 of Set 1 | bathsheba
# Processing Record 41 of Set 1 | ferme-neuve
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | bubaque
# Processing Record 45 of Set 1 | namatanai
# Processing Record 46 of Set 1 | miramar
# Processing Record 47 of Set 1 | zhifang
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | saint-francois
# Processing Record 1 of Set 2 | port elizabeth
# Processing Record 2 of Set 2 | mount gambier
# Processing Record 3 of Set 2 | cabo san lucas
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | clyde river
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | trairi
# City not found. Skipping...
# Processing Record 9 of Set 2 | fare
# Processing Record 10 of Set 2 | talnakh
# Processing Record 11 of Set 2 | turukhansk
# Processing Record 12 of Set 2 | namibe
# Processing Record 13 of Set 2 | kavieng
# Processing Record 14 of Set 2 | wagar
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | paamiut
# Processing Record 17 of Set 2 | vardo
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | bestobe
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | ilulissat
# Processing Record 23 of Set 2 | flinders
# Processing Record 24 of Set 2 | fortuna
# Processing Record 25 of Set 2 | marabba
# Processing Record 26 of Set 2 | romny
# Processing Record 27 of Set 2 | chabahar
# Processing Record 28 of Set 2 | camacha
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | olafsvik
# Processing Record 31 of Set 2 | kyabe
# Processing Record 32 of Set 2 | bambous virieux
# Processing Record 33 of Set 2 | nova olimpia
# Processing Record 34 of Set 2 | ambilobe
# Processing Record 35 of Set 2 | ahipara
# Processing Record 36 of Set 2 | airai
# Processing Record 37 of Set 2 | sechura
# Processing Record 38 of Set 2 | nome
# Processing Record 39 of Set 2 | shimoda
# Processing Record 40 of Set 2 | hofn
# Processing Record 41 of Set 2 | broome
# City not found. Skipping...
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | mogadishu
# Processing Record 44 of Set 2 | buala
# Processing Record 45 of Set 2 | prince rupert
# Processing Record 46 of Set 2 | lakes entrance
# Processing Record 47 of Set 2 | chuy
# City not found. Skipping...
# Processing Record 48 of Set 2 | moerai
# Processing Record 49 of Set 2 | sinalunga
# Processing Record 1 of Set 3 | chapais
# Processing Record 2 of Set 3 | tilichiki
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | oktyabrskiy
# Processing Record 5 of Set 3 | tierralta
# Processing Record 6 of Set 3 | chifeng
# Processing Record 7 of Set 3 | pocone
# Processing Record 8 of Set 3 | klaksvik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 3 | yumen
# Processing Record 10 of Set 3 | russell
# City not found. Skipping...
# Processing Record 11 of Set 3 | bilma
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | ajuchitlan
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | hamilton
# Processing Record 16 of Set 3 | asau
# Processing Record 17 of Set 3 | guaca
# Processing Record 18 of Set 3 | itarema
# Processing Record 19 of Set 3 | giyani
# Processing Record 20 of Set 3 | castro
# City not found. Skipping...
# Processing Record 21 of Set 3 | dryden
# Processing Record 22 of Set 3 | antalaha
# Processing Record 23 of Set 3 | coihaique
# Processing Record 24 of Set 3 | anadyr
# Processing Record 25 of Set 3 | khimki
# Processing Record 26 of Set 3 | grand river south east
# Processing Record 27 of Set 3 | fez
# City not found. Skipping...
# Processing Record 2 of Set 5 | porto-vecchio
# Processing Record 3 of Set 5 | isangel
# Processing Record 4 of Set 5 | half moon bay
# Processing Record 5 of Set 5 | tura
# Processing Record 6 of Set 5 | husavik
# Processing Record 7 of Set 5 | bako
# City not found. Skipping...
# Processing Record 8 of Set 5 | west wendover
# Processing Record 9 of Set 5 | nagorsk
# Processing Record 10 of Set 5 | vila
# City not found. Skipping...
# Processing Record 11 of Set 5 | kahului
# Processing Record 12 of Set 5 | stromness
# Processing Record 13 of Set 5 | kaitangata
# Processing Record 14 of Set 5 | mareeba
# Processing Record 15 of Set 5 | lashio
# Processing Record 16 of Set 5 | malkangiri
# Processing Record 17 of Set 5 | mahebourg
# City not found. Skipping...
# Processing Record 18 of Set 5 | pervomaysk
# Processing Record 19 of Set 5 | tiksi
# Processing Record 20 of Set 5 | kaspiyskiy
# Processing Record 21 of Set 5 | ozernovskiy
# Processing Record 22 of Set 5 | thinadhoo
# Processing Record 23 of Set 5 | majene
# Processing Record 24 of Set 5 | cavalcante
# Processing Record 25 of Set 5 | hithadhoo
# Processing Record 26 of Set 5 | cockburn town
# Processing Record 27 of Set 5 | sao filipe
# Processing Record 28 of Set 5 | maputo
# Processing Record 29 of Set 5 | nizwa
# Processing Record 30 of Set 5 | hit
# Processing Record 31 of Set 5 | arica
# Processing Record 32 of Set 5 | itoman
# City not found. Skipping...
# Processing Record 33 of Set 5 | paita
# Processing Record 34 of Set 5 | black river
# Processing Record 35 of Set 5 | torbay
# Processing Record 36 of Set 5 | havoysund
# Processing Record 37 of Set 5 | abu samrah
# Processing Record 38 of Set 5 | mao
# Processing Record 39 of Set 5 | cartagena
# Processing Record 40 of Set 5 | pravia
# Processing Record 41 of Set 5 | manbij
# City not found. Skipping...
# Processing Record 42 of Set 5 | fayaoue
# Processing Record 43 of Set 5 | lebu
# Processing Record 44 of Set 5 | tessalit
# Processing Record 45 of Set 5 | tandil
# Processing Record 46 of Set 5 | akyab
# Processing Record 47 of Set 5 | vasai
# Processing Record 48 of Set 5 | metro
# Processing Record 49 of Set 5 | sitka
# Processing Record 1 of Set 6 | tasiilaq
# Processing Record 2 of Set 6 | qui nhon
# Processing Record 3 of Set 6 | nikitinskiy
# Processing Record 4 of Set 6 | kaeo
# Processing Record 5 of Set 6 | mount pleasant
# Processing Record 6 of Set 6 | komsomolskiy
# Processing Record 7 of Set 6 | nishihara
# Processing Record 8 of Set 6 | selma
# Processing Record 9 of Set 6 | constitucion
# Processing Record 10 of Set 6 | wooster
# Processing Record 11 of Set 6 | talcahuano
# Processing Record 12 of Set 6 | athabasca
# Processing Record 13 of Set 6 | noumea
# Processing Record 14 of Set 6 | cidreira
# Processing Record 15 of Set 6 | norman wells
# Processing Record 16 of Set 6 | theunissen
# Processing Record 17 of Set 6 | kharp
# Processing Record 18 of Set 6 | calvinia
# Processing Record 19 of Set 6 | laguna
# City not found. Skipping...
# Processing Record 20 of Set 6 | imeni poliny osipenko
# Processing Record 21 of Set 6 | kavaratti
# Processing Record 22 of Set 6 | araouane
# Processing Record 23 of Set 6 | nurota
# Processing Record 24 of Set 6 | garden city
# Processing Record 25 of Set 6 | faya
# Processing Record 26 of Set 6 | nuevo progreso
# Processing Record 27 of Set 6 | salalah
# City not found. Skipping...
# Processing Record 28 of Set 6 | ahuimanu
# Processing Record 29 of Set 6 | valverde del camino
# Processing Record 30 of Set 6 | sistranda
# Processing Record 31 of Set 6 | mys shmidta
# Processing Record 32 of Set 6 | necochea
# City not found. Skipping...
# Processing Record 33 of Set 6 | lahaina
# Processing Record 34 of Set 6 | marzuq
# Processing Record 35 of Set 6 | lasa
# Processing Record 36 of Set 6 | lavrentiya
# City not found. Skipping...
# Processing Record 37 of Set 6 | harper
# Processing Record 38 of Set 6 | westport
# Processing Record 39 of Set 6 | qaqortoq
# Processing Record 40 of Set 6 | luderitz
# Processing Record 41 of Set 6 | tarut
# Processing Record 42 of Set 6 | manga
# Processing Record 43 of Set 6 | makakilo city
# Processing Record 44 of Set 6 | nata
# Processing Record 45 of Set 6 | pitimbu
# Processing Record 46 of Set 6 | ribeira grande
# Processing Record 47 of Set 6 | kamenka
# Processing Record 48 of Set 6 | sambhar
# City not found. Skipping...
# Processing Record 49 of Set 6 | zhaotong
# Processing Record 1 of Set 7 | rio pardo de minas
# Processing Record 2 of Set 7 | mitu
# Processing Record 3 of Set 7 | aasiaat
# Processing Record 4 of Set 7 | asuncion nochixtlan
# Processing Record 5 of Set 7 | nortelandia
# Processing Record 6 of Set 7 | vidim
# Processing Record 7 of Set 7 | bintulu
# Processing Record 8 of Set 7 | chapleau
# Processing Record 9 of Set 7 | tarko-sale
# Processing Record 10 of Set 7 | palu
# Processing Record 11 of Set 7 | staraya mayna
# Processing Record 12 of Set 7 | arbuzynka
# Processing Record 13 of Set 7 | kenai
# Processing Record 14 of Set 7 | labuhan
# Processing Record 15 of Set 7 | daman
# Processing Record 16 of Set 7 | ambatofinandrahana
# Processing Record 17 of Set 7 | sucua
# Processing Record 18 of Set 7 | margate
# City not found. Skipping...
# Processing Record 19 of Set 7 | nanning
# Processing Record 20 of Set 7 | bandarbeyla
# Processing Record 21 of Set 7 | yar-sale
# Processing Record 22 of Set 7 | kpandu
# Processing Record 23 of Set 7 | burnie
# Processing Record 24 of Set 7 | nova varos
# Processing Record 25 of Set 7 | argayash
# Processing Record 26 of Set 7 | myitkyina
# Processing Record 27 of Set 7 | matagami
# Processing Record 28 of Set 7 | agha jari
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 7 | chibuto
# Processing Record 30 of Set 7 | bhatapara
# Processing Record 31 of Set 7 | zaraza
# Processing Record 32 of Set 7 | chandler
# Processing Record 33 of Set 7 | kabinda
# Processing Record 34 of Set 7 | lagoa
# Processing Record 35 of Set 7 | samarinda
# Processing Record 36 of Set 7 | severodvinsk
# Processing Record 37 of Set 7 | rocha
# Processing Record 38 of Set 7 | lyubytino
# Processing Record 39 of Set 7 | policoro
# Processing Record 40 of Set 7 | grand-santi
# Processing Record 41 of Set 7 | biak
# Processing Record 42 of Set 7 | gurupa
# Processing Record 43 of Set 7 | fenoarivo
# City not found. Skipping...
# Processing Record 44 of Set 7 | maumere
# Processing Record 45 of Set 7 | esso
# Processing Record 46 of Set 7 | grand-lahou
# Processing Record 21 of Set 9 | szamotuly
# Processing Record 22 of Set 9 | finschhafen
# Processing Record 23 of Set 9 | vestmannaeyjar
# Processing Record 24 of Set 9 | sorland
# Processing Record 25 of Set 9 | kodinsk
# Processing Record 26 of Set 9 | aracati
# Processing Record 27 of Set 9 | astoria
# Processing Record 28 of Set 9 | qianan
# Processing Record 29 of Set 9 | nueva concepcion
# Processing Record 30 of Set 9 | bourail
# Processing Record 31 of Set 9 | kozhva
# Processing Record 32 of Set 9 | san patricio
# Processing Record 33 of Set 9 | goderich
# Processing Record 34 of Set 9 | vuktyl
# Processing Record 35 of Set 9 | touros
# City not found. Skipping...
# Processing Record 36 of Set 9 | tongren
# Processing Record 37 of Set 9 | cacoal
# Processing Record 38 of Set 9 | livingston
# Processing Record 39 of Set 9 | bilibino
# Processing Record 40 of Set 9 | colares
# Processing Record 41 of Set 9 | hurghada
# City not found. Skipping...
# Processing Record 42 of Set 9 | rawicz
# Processing Record 43 of Set 9 | haukipudas
# Processing Record 44 of Set 9 | bethalto
# Processing Record 45 of Set 9 | zaysan
# Processing Record 46 of Set 9 | arys
# Processing Record 47 of Set 9 | tupik
# Processing Record 48 of Set 9 | honiara
# Processing Record 49 of Set 9 | bhunya
# Processing Record 1 of Set 10 | clearwater
# Processing Record 2 of Set 10 | gilroy
# City not found. Skipping...
# Processing Record 3 of Set 10 | saint-pierre
# Processing Record 4 of Set 10 | mukdahan
# Processing Record 5 of Set 10 | eenhana
# Processing Record 6 of Set 10 | greenwood
# Processing Record 7 of Set 10 | bur gabo
# Processing Record 8 of Set 10 | bima
# Processing Record 9 of Set 10 | alencon
# Processing Record 10 of Set 10 | ibra
# Processing Record 11 of Set 10 | lazaro cardenas
# Processing Record 12 of Set 10 | grado
# Processing Record 13 of Set 10 | nouadhibou
# Processing Record 14 of Set 10 | chaozhou
# Processing Record 15 of Set 10 | asmara
# Processing Record 16 of Set 10 | vabalninkas
# Processing Record 17 of Set 10 | rivera
# Processing Record 18 of Set 10 | nkowakowa
# City not found. Skipping...
# Processing Record 19 of Set 10 | springdale
# Processing Record 20 of Set 10 | gladstone
# Processing Record 21 of Set 10 | zhicheng
# Processing Record 22 of Set 10 | bambanglipuro
# Processing Record 23 of Set 10 | aykhal
# Processing Record 24 of Set 10 | ngunguru
# Processing Record 25 of Set 10 | ostrovnoy
# Processing Record 26 of Set 10 | arandis
# City not found. Skipping...
# Processing Record 27 of Set 10 | hastings
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 28 of Set 10 | blairmore
# Processing Record 29 of Set 10 | haimen
# Processing Record 30 of Set 10 | kruisfontein
# Processing Record 31 of Set 10 | sabalgarh
# City not found. Skipping...
# Processing Record 32 of Set 10 | alofi
# Processing Record 33 of Set 10 | hargeysa
# Processing Record 34 of Set 10 | bam
# Processing Record 35 of Set 10 | daru
# Processing Record 36 of Set 10 | buduslau
# Processing Record 37 of Set 10 | tabuny
# Processing Record 38 of Set 10 | sao domingos
# Processing Record 39 of Set 10 | otradnoye
# City not found. Skipping...
# Processing Record 40 of Set 10 | balabac
# Processing Record 41 of Set 10 | merauke
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 10 | kaputa
# Processing Record 43 of Set 10 | farsund
# Processing Record 44 of Set 10 | gelibolu
# Processing Record 45 of Set 10 | eqbaliyeh
# City not found. Skipping...
# Processing Record 46 of Set 10 | takoradi
# Processing Record 47 of Set 10 | taree
# Processing Record 48 of Set 10 | cayenne
# Processing Record 49 of Set 10 | boa vista
# City not found. Skipping...
# Processing Record 1 of Set 11 | naze
# Processing Record 2 of Set 11 | voskresenskoye
# Processing Record 3 of Set 11 | ampanihy
# Processing Record 4 of Set 11 | omaruru
# Processing Record 5 of Set 11 | sao joao da barra
# Processing Record 6 of Set 11 | port blair
# Processing Record 7 of Set 11 | kajiado
# City not found. Skipping...
# Processing Record 8 of Set 11 | poddorye
# Processing Record 9 of Set 11 | korla
# Processing Record 10 of Set 11 | cherskiy
# Processing Record 11 of Set 11 | sobolevo
# Processing Record 12 of Set 11 | gat
# Processing Record 13 of Set 11 | minggang
# City not found. Skipping...
# Processing Record 14 of Set 11 | lufilufi
# Processing Record 15 of Set 11 | dabat
# Processing Record 16 of Set 11 | jabinyanah
# Processing Record 17 of Set 11 | perth
# Processing Record 18 of Set 11 | mayo
# Processing Record 19 of Set 11 | aitape
# Processing Record 20 of Set 11 | ornskoldsvik
# Processing Record 21 of Set 11 | morondava
# Processing Record 22 of Set 11 | manta
# Processing Record 23 of Set 11 | dunedin
# Processing Record 24 of Set 11 | poole
# Processing Record 25 of Set 11 | yakeshi
# Processing Record 26 of Set 11 | aguimes
# Processing Record 27 of Set 11 | olivenza
# Processing Record 28 of Set 11 | byron bay
# Processing Record 29 of Set 11 | nalut
# Processing Record 30 of Set 11 | bhadrak
# Processing Record 31 of Set 11 | bonthe
# Processing Record 32 of Set 11 | nuuk
# Processing Record 33 of Set 11 | nhulunbuy
# Processing Record 34 of Set 11 | plettenberg bay
# Processing Record 35 of Set 11 | colquechaca
# Processing Record 36 of Set 11 | iqaluit
# Processing Record 37 of Set 11 | khash
# Processing Record 38 of Set 11 | luena
# City not found. Skipping...
# Processing Record 39 of Set 11 | gijon
# City not found. Skipping...
# Processing Record 40 of Set 11 | kleive
# Processing Record 41 of Set 11 | ondarroa
# Processing Record 42 of Set 11 | sabha
# Processing Record 43 of Set 11 | banda aceh
# Processing Record 44 of Set 11 | buchanan
# Processing Record 45 of Set 11 | bad bramstedt
# Processing Record 46 of Set 11 | sterling
# Processing Record 47 of Set 11 | okulovka
# Processing Record 48 of Set 11 | huilong
# Processing Record 49 of Set 11 | mandalgovi
# City not found. Skipping...
# Processing Record 1 of Set 12 | omsukchan
# Processing Record 2 of Set 12 | panaba
# Processing Record 3 of Set 12 | aksarka
# Processing Record 4 of Set 12 | iracoubo
# Processing Record 5 of Set 12 | inhambane
# Processing Record 6 of Set 12 | san quintin
# Processing Record 7 of Set 12 | cap malheureux
# Processing Record 8 of Set 12 | denpasar
# Processing Record 9 of Set 12 | bindura
# Processing Record 10 of Set 12 | porto novo
# Processing Record 11 of Set 12 | alakurtti
# Processing Record 12 of Set 12 | znin
# Processing Record 13 of Set 12 | kardailovo
# Processing Record 14 of Set 12 | uyuni
# Processing Record 15 of Set 12 | okato
# Processing Record 16 of Set 12 | les cayes
# Processing Record 17 of Set 12 | eyl
# Processing Record 18 of Set 12 | juarez
# Processing Record 19 of Set 12 | rodeo
# Processing Record 20 of Set 12 | redmond
# Processing Record 21 of Set 12 | sao borja
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City":city_new,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}

# %%
weather_dataframe = pd.DataFrame(weather_dict)
weather_dataframe.head()
# Out:
#                    City  Cloudiness Country        Date  Humidity    Lat  \
# 0          krasnoselkup          43      RU  1584981092        91  65.70
# 1            nikolskoye           8      RU  1584981093        40  59.70
# 2               oistins          40      BB  1584981093        58  13.07
# 3  vila franca do campo          20      PT  1584981094        55  42.03
# 4             ekuvukeni          92      ZA  1584981094        82 -28.47
#
#      Lng  Max Temp  Wind Speed
# 0  82.47      0.43       19.93
# 1  30.79     33.80        6.71
# 2 -59.53     86.00       20.80
# 3  -8.16     66.20        6.93
# 4  30.16     65.23        5.91

# %%
weather_dataframe.to_csv(output_data_file)

# %%
weather_dataframe.count()
# Out:
# City          560
# Cloudiness    560
# Country       560
# Date          560
# Humidity      560
# Lat           560
# Lng           560
# Max Temp      560
# Wind Speed    560
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Max Temp"],marker="o")
plt.title(f'City Latitude vs. Max Temperature {time.strftime("%m/%d/%Y")}')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (True)
plt.savefig("output_data/fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_dataframe["Lat"], weather_dataframe["Humidity"], marker="o")
plt.title(f'City Latitude vs. Humidity {time.strftime("%m/%d/%Y")}')
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("output_data/fig2.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dataframe["Lat"], weather_dataframe["Cloudiness"], marker="o")
plt.title(f'City Latitude vs. Max Cloudiness {time.strftime("%m/%d/%Y")}')
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("output_data/fig3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_dataframe["Lat"], weather_dataframe["Wind Speed"], marker="o")
plt.title(f'City Latitude vs. Wind Speed {time.strftime("%m/%d/%Y")}')
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("output_data/fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_dataframe.loc[pd.to_numeric(weather_dataframe["Lat"]).astype(float) > 0, :]
southern_df = weather_dataframe.loc[pd.to_numeric(weather_dataframe["Lat"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# Regression line equation is: y = -1.17x + 97.18
# The r-squared is: -0.8833124299849796
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
# Out:
# Regression line equation is: y = 0.45x + 82.68
# The r-squared is: 0.5618536726704031
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = 0.27x + 54.8
# The r-squared is: 0.2362075161116282
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.37x + 79.74
# The r-squared is: 0.25779806375295744
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.15x + 46.99
# The r-squared is: 0.08076687954235925
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.58x + 70.5
# The r-squared is: 0.2232450258885491
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.1x + 6.01
# The r-squared is: 0.28282650850693464
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.13x + 5.3
# The r-squared is: -0.3188067654496399
# The regression does not display much of a correlation between the data sets.
